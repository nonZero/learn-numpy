# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Create the following images with masks:
# <img src="city-round1.png">
# <img src="city-round2.png">

# %%
a = imread("city.jpeg") / 256
imshow(a)
