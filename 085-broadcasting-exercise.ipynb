# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# #### Drill #1
# ![image.png](attachment:img2.png)

# %% [markdown]
# #### Drill #2
# ![image.png](attachment:img4.png)

# %% [markdown]
# #### Drill #3
# ![image.png](attachment:img6.png)

# %% [markdown]
# #### Drill #4
# ![image.png](attachment:img8.png)

# %% [markdown]
# #### Drill #5
# ![image.png](attachment:img10.png)

# %% [markdown]
# #### Drill #6
# ![image.png](attachment:img12.png)

# %% [markdown]
# #### Drill #7
# ![image.png](attachment:img14.png)

# %% [markdown]
# #### Drill #8
# ![image.png](attachment:img16.png)

# %% [markdown]
# #### Drill #9
# ![image.png](attachment:img18.png)

# %% [markdown]
# #### Drill #10
# ![image.png](attachment:img20.png)

# %% [markdown]
# #### Drill #11
# ![image.png](attachment:img22.png)

# %% [markdown]
# #### Drill #12
# ![image.png](attachment:img24.png)

# %% [markdown]
# #### Drill #13
# ![image.png](attachment:img26.png)

# %% [markdown]
# #### Drill #14
# ![image.png](attachment:img28.png)

# %% [markdown]
# #### Drill #15
# ![image.png](attachment:img30.png)
