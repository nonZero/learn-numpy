# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Exercise: Indexing and Slicing
#
# Get the sample image from here: <https://gist.githubusercontent.com/nonZero/f40bbcc9cda84f431a607728de878bd9/raw/9e1917ce876095be11b18d416ffae5db1a4384b4/city.jpeg>
#
# Save it as `city.jpeg` in your working folder.
#
# Use `imread(filename)` to load an image file:

# %%
a = imread("city.jpeg")

# %%
a.shape, a.dtype
# Out:
# ((426, 640, 3), dtype('uint8'))

# %%
imshow(a)

# %% [markdown]
# ## Part 1: Show channels r,g and b

# %% [markdown]
# ## Part 2: Show the image flipped vertically

# %% [markdown]
# ## Part 3: Show the image flipped horizontally

# %% [markdown]
# ## Part 4: Show the image with channels R and B swapped.

# %% [markdown]
# ## Part 5: show only this part of the image
# ![partial image](city-part.png)
