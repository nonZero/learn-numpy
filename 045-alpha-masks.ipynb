# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
a = imread("pencils.jpeg") / 256
imshow(a)

# %%
figsize(12,4)
for i, c in enumerate("RGB"):
    subplot(1, 3, i+1)
    hist(a[:,:,i].ravel(), bins=64,color=c)
    title(c)

# %%
figsize(6,6)
xlabel("red")
ylabel("green")
_ = hist2d(a[:,:,0].ravel(), a[:,:,1].ravel(), bins=64, cmap=cm.hot)

# %% [markdown]
# # Adding an Alpha (Transparency) Channel

# %%
y = np.ones(a.shape[0])
x = np.linspace(0, 1, a.shape[1])
alpha = np.multiply.outer(y, x)
alpha.shape
# Out:
# (480, 640)

# %%
rgba = dstack((a, alpha))
rgba.shape
# Out:
# (480, 640, 4)

# %%
_ = imshow(rgba)

# %% [markdown]
# # Converting to Grayscale
# * More Info: https://en.wikipedia.org/wiki/Grayscale#Converting_color_to_grayscale

# %%
def rgb2gray(rgb):
    return rgb[...,:3] @ [0.299, 0.587, 0.114]

# %%
b = rgb2gray(a)
b.shape
# Out:
# (480, 640)

# %%
imshow(b, cmap=cm.gray, vmin=0, vmax=1)
colorbar()
